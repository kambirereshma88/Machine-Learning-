# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection and Processing

# %%
loan_dataset=pd.read_csv("Loan_dataset.csv")

# %%
loan_dataset
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
#number of rows and column
loan_dataset.shape
# Out:
# (614, 13)

# %%
# statistical measures
loan_dataset.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#number of missing values in each column
loan_dataset.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
#dropping all missing values 
loan_dataset=loan_dataset.dropna()

# %%
loan_dataset.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# #Label Encoding

# %%
#label encoding    #this is dictionary dataset where yes = 1 and n = 0
loan_dataset.replace({"Loan_Status":{"N":0,"Y":1}},inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\3748334671.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   loan_dataset.replace({"Loan_Status":{"N":0,"Y":1}},inplace=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\3748334671.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   loan_dataset.replace({"Loan_Status":{"N":0,"Y":1}},inplace=True)

# %%
#Printing the first 5 rows of dataframe to check Loan_staus value 

loan_dataset.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History Property_Area  Loan_Status
# 1             1.0         Rural            0
# 2             1.0         Urban            1
# ...

# %%
#Dependent column values

loan_dataset['Dependents'].value_counts()
# Out:
# Dependents
# 0     274
# 2      85
# 1      80
# 3+     41
# Name: count, dtype: int64

# %%
#replacing the value of 3+ to 4

loan_dataset = loan_dataset.replace('3+',4)

# %%
#Dependent column values

loan_dataset['Dependents'].value_counts()
# Out:
# Dependents
# 0    274
# 2     85
# 1     80
# 4     41
# Name: count, dtype: int64

# %% [markdown]
# # Data Visualization

# %%
#education and loan status

sns.countplot(data=loan_dataset,x="Education",hue="Loan_Status")
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
#martial status and loan Status
# if a person is married then loan is approved so that any one from both can contribute to loan  
sns.countplot(data=loan_dataset,x="Married",hue="Loan_Status")
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
# gender and loan status
sns.countplot(data=loan_dataset,x="Gender",hue="Loan_Status")
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#convert categrical columns to numerical values

loan_dataset.replace({"Married":{"No":0,"Yes":1},"Gender":{"Male":1,"Female":0},"Self_Employed":{'No':0 ,'Yes':1},'Property_Area':{
    'Rural':0,'Semiurban':1,'Urban':2},'Education':{'Graduate':1,'Not Graduate':0}},inplace=True)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13232\2964617400.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   loan_dataset.replace({"Married":{"No":0,"Yes":1},"Gender":{"Male":1,"Female":0},"Self_Employed":{'No':0 ,'Yes':1},'Property_Area':{

# %%
# here we have converted all categorical data into numerical data
loan_dataset.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1  LP001003       1        1          1          1              0
# 2  LP001005       1        1          0          1              1
# 3  LP001006       1        1          0          0              0
# 4  LP001008       1        0          0          1              0
# 5  LP001011       1        1          2          1              1
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 5             5417             4196.0       267.0             360.0
#
#    Credit_History  Property_Area  Loan_Status
# 1             1.0              0            0
# 2             1.0              2            1
# ...

# %%
#we will separate all data  and label   
#separating the data and  label 
x=loan_dataset.drop(columns=['Loan_ID','Loan_Status'],axis=1)
y=loan_dataset['Loan_Status']

# %%
x
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1        1          1          1              0             4583
# 2         1        1          0          1              1             3000
# 3         1        1          0          0              0             2583
# 4         1        0          0          1              0             6000
# 5         1        1          2          1              1             5417
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          1              0             2900
# 610       1        1          4          1              0             4106
# 611       1        1          1          1              0             8072
# 612       1        1          2          1              0             7583
# 613       0        0          0          1              1             4583
#
# ...

# %%
y
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 480, dtype: int64

# %% [markdown]
# # Splitting of data into training and testing

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
#splited data into training and testing data
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (480, 11) (384, 11) (96, 11)

# %% [markdown]
# # Training model

# %% [markdown]
# # Applying algorithm

# %% [markdown]
# # Applying Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report, accuracy_score

# Train and evaluate Logistic Regression
logistic_model = LogisticRegression(random_state=42)
logistic_model.fit(x_train, y_train)
y_pred_logistic = logistic_model.predict(x_test)

print("Logistic Regression")
print("Accuracy:", accuracy_score(y_test, y_pred_logistic))
print(classification_report(y_test, y_pred_logistic))
# Out:
# Logistic Regression
# Accuracy: 0.75
#               precision    recall  f1-score   support
#
#            0       0.93      0.38      0.54        37
#            1       0.72      0.98      0.83        59
#
#     accuracy                           0.75        96
#    macro avg       0.82      0.68      0.68        96
# weighted avg       0.80      0.75      0.72        96
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# # Applying Support Vector Machine Model

# %%
from sklearn.svm import SVC

# Train and evaluate SVM
svm_model = SVC(random_state=42, kernel='linear')
svm_model.fit(x_train, y_train)
y_pred_svm = svm_model.predict(x_test)

print("Support Vector Machine")
print("Accuracy:", accuracy_score(y_test, y_pred_svm))
print(classification_report(y_test, y_pred_svm))
# Out:
# Support Vector Machine
# Accuracy: 0.7083333333333334
#               precision    recall  f1-score   support
#
#            0       0.80      0.32      0.46        37
#            1       0.69      0.95      0.80        59
#
#     accuracy                           0.71        96
#    macro avg       0.75      0.64      0.63        96
# weighted avg       0.73      0.71      0.67        96

# %% [markdown]
# # Applying DecisionTreeClassifier Model

# %%
from sklearn.tree import DecisionTreeClassifier

# Train and evaluate Decision Tree
dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(x_train, y_train)
y_pred_dt = dt_model.predict(x_test)

print("Decision Tree")
print("Accuracy:", accuracy_score(y_test, y_pred_dt))
print(classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree
# Accuracy: 0.6979166666666666
#               precision    recall  f1-score   support
#
#            0       0.62      0.54      0.58        37
#            1       0.73      0.80      0.76        59
#
#     accuracy                           0.70        96
#    macro avg       0.68      0.67      0.67        96
# weighted avg       0.69      0.70      0.69        96

# %% [markdown]
# # Applying RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# Train and evaluate Random Forest
rf_model = RandomForestClassifier(random_state=42, n_estimators=100)
rf_model.fit(x_train, y_train)
y_pred_rf = rf_model.predict(x_test)

print("Random Forest")
print("Accuracy:", accuracy_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest
# Accuracy: 0.7708333333333334
#               precision    recall  f1-score   support
#
#            0       0.89      0.46      0.61        37
#            1       0.74      0.97      0.84        59
#
#     accuracy                           0.77        96
#    macro avg       0.82      0.71      0.72        96
# weighted avg       0.80      0.77      0.75        96

# %% [markdown]
# # Applying GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Train and evaluate Gradient Boosting
gb_model = GradientBoostingClassifier(random_state=42)
gb_model.fit(x_train, y_train)
y_pred_gb = gb_model.predict(x_test)

print("Gradient Boosting")
print("Accuracy:", accuracy_score(y_test, y_pred_gb))
print(classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting
# Accuracy: 0.7708333333333334
#               precision    recall  f1-score   support
#
#            0       0.83      0.51      0.63        37
#            1       0.75      0.93      0.83        59
#
#     accuracy                           0.77        96
#    macro avg       0.79      0.72      0.73        96
# weighted avg       0.78      0.77      0.76        96

# %% [markdown]
# # Accuracy Scores for all Models

# %%
# Store accuracy scores for all models
results = {
    "Logistic Regression": accuracy_score(y_test, y_pred_logistic),
    "Decision Tree": accuracy_score(y_test, y_pred_dt),
    "Random Forest": accuracy_score(y_test, y_pred_rf),
    "Support Vector Machine": accuracy_score(y_test, y_pred_svm),
    "Gradient Boosting": accuracy_score(y_test, y_pred_gb),
}

# Print results
print("Model Comparison:")
for model, accuracy in results.items():
    print(f"{model}: {accuracy:.2f}")
# Out:
# Model Comparison:
# Logistic Regression: 0.75
# Decision Tree: 0.70
# Random Forest: 0.77
# Support Vector Machine: 0.71
# Gradient Boosting: 0.77

# %% [markdown]
# # INSIGHTS

# %% [markdown]
# ## After comparing the models:
#
# Best Algorithm: The algorithm with the highest accuracy and F1-score are Gradient Boosting or Random Forest for given data.

# %% [markdown]
# # Applying Logistic Regression

# %%
#Logistic Regression model
lr=LogisticRegression()

# %%
def mymodel(model):
  model.fit(x_train,y_train)
  ypred=model.predict(x_test)
  print(classification_report(y_test,ypred))
  return model

# %%
mymodel(lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.38      0.54        37
#            1       0.72      0.98      0.83        59
#
#     accuracy                           0.75        96
#    macro avg       0.82      0.68      0.68        96
# weighted avg       0.80      0.75      0.72        96
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# # Applying DecisionTreeClassifier

# %%
#decision tree classifier model
from sklearn.tree import DecisionTreeClassifier
dt= DecisionTreeClassifier()

# %%
mymodel(dt)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.51      0.58        37
#            1       0.73      0.83      0.78        59
#
#     accuracy                           0.71        96
#    macro avg       0.69      0.67      0.68        96
# weighted avg       0.70      0.71      0.70        96
# DecisionTreeClassifier()

# %% [markdown]
# # Applying RandonForestClassifier

# %%
#random forest model
from sklearn.ensemble import RandomForestClassifier
rm=RandomForestClassifier()

# %%
mymodel(rm)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.46      0.60        37
#            1       0.74      0.95      0.83        59
#
#     accuracy                           0.76        96
#    macro avg       0.79      0.70      0.71        96
# weighted avg       0.78      0.76      0.74        96
# RandomForestClassifier()

# %% [markdown]
# # Applying Support Vector Machine

# %%
# Support vector machine model
from sklearn.svm import SVC
svc=SVC()

# %%
mymodel(svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        37
#            1       0.61      0.98      0.75        59
#
#     accuracy                           0.60        96
#    macro avg       0.31      0.49      0.38        96
# weighted avg       0.38      0.60      0.46        96
# SVC()

# %% [markdown]
# # Applying GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gd = GradientBoostingClassifier()

# %%
mymodel(gd)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.51      0.64        37
#            1       0.76      0.95      0.84        59
#
#     accuracy                           0.78        96
#    macro avg       0.81      0.73      0.74        96
# weighted avg       0.80      0.78      0.77        96
# GradientBoostingClassifier()

# %% [markdown]
# # Printing Results For Model Comparison

# %%
# Print results
print("Model Comparison:")
for mymodel, accuracy in results.items():
    print(f"{mymodel}: {accuracy:.2f}")
# Out:
# Model Comparison:
# Logistic Regression: 0.75
# Decision Tree: 0.70
# Random Forest: 0.77
# Support Vector Machine: 0.71
# Gradient Boosting: 0.77

# %% [markdown]
# # After comparing the models:
# Best Algorithm: The algorithm with the highest accuracy and F1-score are Gradient Boosting or Random Forest for given data.

# %% [markdown]
# # Hypertunning of Model

# %% [markdown]
# ## 1...Hypertunning for SVM

# %%
#hypertuning of c and gamma
from sklearn.model_selection import GridSearchCV
param_grid={'C':[1,10],'gamma':[1,10],'kernel':['rbf']}

# %%
gd=GridSearchCV(svc,param_grid,verbose=3)#verbose (value)  is used to display information
gd.fit(x_train,y_train)                    #gridsearchcv is class   and param_grid=parameter
ypred=gd.predict(x_test)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.701 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.711 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=10, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=10, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=10, kernel=rbf;, score=0.714 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=10, kernel=rbf;, score=0.701 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=10, kernel=rbf;, score=0.711 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.714 total time=   0.0s
# ...

# %%
gd.best_params_      #this to find best value
# Out:
# {'C': 1, 'gamma': 1, 'kernel': 'rbf'}

# %% [markdown]
# ## 2...Hypertuning for LogisticRegression

# %%
#hypertuning with solver
#solver=lbfgs  by default hyperparameter
#build model

lr=LogisticRegression(solver='liblinear')
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.43      0.59        37
#            1       0.73      0.98      0.84        59
#
#     accuracy                           0.77        96
#    macro avg       0.84      0.71      0.72        96
# weighted avg       0.81      0.77      0.75        96

# %%
lr=LogisticRegression(solver='newton-cg')
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.43      0.59        37
#            1       0.73      0.98      0.84        59
#
#     accuracy                           0.77        96
#    macro avg       0.84      0.71      0.72        96
# weighted avg       0.81      0.77      0.75        96

# %%
lr=LogisticRegression(solver='sag')
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        37
#            1       0.61      1.00      0.76        59
#
#     accuracy                           0.61        96
#    macro avg       0.31      0.50      0.38        96
# weighted avg       0.38      0.61      0.47        96
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
lr=LogisticRegression(solver='saga')    #sag and saga work on scalled data and give a good accuracy
lr.fit(x_train,y_train)
ypred=lr.predict(x_test)
print(classification_report(y_test,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        37
#            1       0.61      1.00      0.76        59
#
#     accuracy                           0.61        96
#    macro avg       0.31      0.50      0.38        96
# weighted avg       0.38      0.61      0.47        96
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1509: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from sklearn.model_selection import GridSearchCV

param_grid={'C':[1,10],'solver':['lbfgs','liblinear'],'penalty':['l2']}

# %%
gd_lr=GridSearchCV(lr,param_grid,verbose=3)#verbose (value)  is used to display information
gd_lr.fit(x_train,y_train)                    #gridsearchcv is class   and param_grid=parameter
ypred=gd.predict(x_test)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.792 total time=   0.0s
# [CV 2/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.792 total time=   0.0s
# [CV 3/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.844 total time=   0.0s
# [CV 4/5] END .....C=1, penalty=l2, solver=lbfgs;, score=0.792 total time=   0.0s
# C:\Anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
gd_lr.best_params_      #this to find best value
# Out:
# {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print("Logistic Regression Best Params:", gd_lr.best_params_)
# Out:
# Logistic Regression Best Params: {'C': 1, 'penalty': 'l2', 'solver': 'liblinear'}

# %%
print("Accuracy:", accuracy_score(y_test, gd_lr.predict(x_test)))
# Out:
# Accuracy: 0.7708333333333334

# %% [markdown]
# # 3...Hypertuning for RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)

# %%
param_grid_rf = {
    'n_estimators': [50, 100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
gds_rf = GridSearchCV(estimator=rf, param_grid=param_grid_rf, cv=5, verbose=3, n_jobs=-1)
gds_rf.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
print("Random Forest Best Params:", gds_rf.best_params_)
print("Accuracy:", accuracy_score(y_test, gds_rf.predict(x_test)))
# Out:
# Random Forest Best Params: {'max_depth': 10, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 50}
# Accuracy: 0.78125

# %% [markdown]
# # 4...Hypertuning for Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbc = GradientBoostingClassifier(random_state=42)

# %%
param_grid_gbc = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7]
}

# %%
gds_gbc = GridSearchCV(estimator=gbc, param_grid=param_grid_gbc, cv=5, verbose=3)
gds_gbc.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.779 total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.740 total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.883 total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.766 total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=0.737 total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.805 total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.740 total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.896 total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=0.792 total time=   0.2s
# ...

# %%
print("Gradient Boosting Best Params:", gds_gbc.best_params_)
print("Accuracy:", accuracy_score(y_test, gds_gbc.predict(x_test)))
# Out:
# Gradient Boosting Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
# Accuracy: 0.78125

# %% [markdown]
# # 5...Hypertuning for Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)

# %%
param_grid_dt = {
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# %%
gds_dt = GridSearchCV(estimator=dt, param_grid=param_grid_dt, cv=5, verbose=3)
gds_dt.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.753 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.740 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.870 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.792 total time=   0.0s
# [CV 5/5] END max_depth=3, min_samples_leaf=1, min_samples_split=2;, score=0.803 total time=   0.0s
# [CV 1/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.753 total time=   0.0s
# [CV 2/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.740 total time=   0.0s
# [CV 3/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.870 total time=   0.0s
# [CV 4/5] END max_depth=3, min_samples_leaf=1, min_samples_split=5;, score=0.792 total time=   0.0s
# ...

# %%
print("Decision Tree Best Params:", gds_dt.best_params_)
print("Accuracy:", accuracy_score(y_test, gds_dt.predict(x_test)))
# Out:
# Decision Tree Best Params: {'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Accuracy: 0.7708333333333334

# %% [markdown]
# # 6...Hypertuning for XGBoost Classifier

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()

# %%
param_grid_xgb = {
    'learning_rate': [0.01, 0.1, 0.2],
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 7]
}

# %%
gds_xgb = GridSearchCV(estimator=xgb, param_grid=param_grid_xgb, cv=5, verbose=3)
gds_xgb.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=nan total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=3, n_estimators=50;, score=nan total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=3, n_estimators=100;, score=nan total time=   0.0s
# ...

# %%
print("XGBoost Best Params:", gds_xgb.best_params_)
print("Accuracy:", accuracy_score(y_test, gds_xgb.predict(x_test)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 print("XGBoost Best Params:", gds_xgb.best_params_)
#       2 print("Accuracy:", accuracy_score(y_test, gds_xgb.predict(x_test)))
#
# AttributeError: 'GridSearchCV' object has no attribute 'best_params_'

# %%
# Cross validation
from sklearn.model_selection import cross_val_score
cross_validation = cross_val_score(estimator = xgb_classifier_pt, X = X_tra
print("Cross validation accuracy of XGBoost model = ", cross_validation)
print("\nCross validation mean accuracy of XGBoost model = ", cross_validat
